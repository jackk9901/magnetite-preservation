# %% [markdown]
# # Magnetic and Diagenetic Analyses of Ishikawa (2002)
# _____
#
# Paper doi: https://link.springer.com/content/pdf/10.1186/BF03352436.pdf, https://doi.org/10.2973/odp.proc.sr.180.162.2002
#
# Core: ODP Leg 180 Site 1109 (9º30.392'S, 151º34.390'E)
#
# Water depth: 2211 m
#
# Data in analysis: Magnetite ppm (from Ms measurements), sedimentation rate, total organic carbon, pore water chemistry.

# %%
# import packages
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import data_fns
# %matplotlib inline
plt.rcParams["pdf.fonttype"] = "3"
plt.rcParams["font.family"] = "Avenir"

# %%
# read in data
magn = pd.read_excel("data/ishikawa2002/1109.xlsx", sheet_name="1109 Ms")
geochem = pd.read_excel("data/ishikawa2002/1109.xlsx", sheet_name="geochem")
toc = pd.read_excel("data/ishikawa2002/1109.xlsx", sheet_name="TOC")
ages = pd.read_excel("data/ishikawa2002/1109.xlsx", sheet_name="ages")

# only unit adjustment is magnetite
magn["Magnetite [ppm]"] = (magn["Ms (Am^2/kg)"] * 10**6) / 92
magn["Magnetite [wt. %]"] = (magn["Ms (Am^2/kg)"] * 10**2) / 92
# Out:
# /Users/jackkreisler/opt/anaconda3/lib/python3.9/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
# calculate sed rates
sed_rates = data_fns.sed_rates(ages["Age (ma)"], ages["Depth (mbsf)"])

# %%
# combine stuff together
magn_df = pd.DataFrame({"Depth [mbsf]":magn["Depth (mbsf)"], "Magnetite [ppm]":magn["Magnetite [ppm]"], "Magnetite [wt. %]":magn["Magnetite [wt. %]"]})
geochem_df = pd.DataFrame({"Depth [mbsf]":geochem["Depth (mbsf)"], "Sulfate [mM]":geochem["Sulfate(SO4) (mM)"]})
toc_df = pd.DataFrame({"Depth [mbsf]":toc["Depth (mbsf)"], "TOC [wt. %]":toc["ORG_C (wt %)"]})
seds_df = pd.DataFrame({"Depth [mbsf]":ages["Depth (mbsf)"], "Sedimentation Rate [m/Myr]":sed_rates})

comb_df = pd.concat([magn_df, geochem_df, toc_df, seds_df]).sort_values(by="Depth [mbsf]").reset_index(drop=True)

# %%
# interpolate
# the last sed rate point is at 664, final Ms point at 745 (14 total below 664)
# choosing to extend the sed rates down, open to revisiting this later
interpolated = data_fns.interpolate(comb_df, ["Sulfate [mM]", "TOC [wt. %]"])

# %%
# downcore plots
colors = ["r", "b", "r", "g"]
markers = [".", "+", "^", "x"]
comp_markers = [".", ".", ".", "."]
dc_fig, dc_axs = data_fns.plot_dc(["Magnetite [ppm]", "Sulfate [mM]", "TOC [wt. %]", "Sedimentation Rate [m/Myr]"], comb_df, colors, markers)
dc_fig.suptitle("Downcore Parameters of ODP 180-1109", x=0.55)
#dc_axs[0].set_ylim(40, 0)
dc_axs[0].set_xlim(xmax=7500)
dc_axs[2].set_xlim(xmax=2)
dc_axs[3].set_xlabel("Sedimentation Rate\n[m/Myr]")
plt.tight_layout()
dc_fig.savefig("outputs/ishikawa2002/1109/dc1-aug23.pdf", bbox_inches="tight")

# %%
# comparison plots (exclude 0th color so that things show up in standard colors
comp_figs, comp_axs = data_fns.plot_comp(["Sulfate [mM]", "TOC [wt. %]"], interpolated, colors[1:], comp_markers)
comp_axs[0].set(xlabel="Magnetite [ppm]", ylabel="Sulfate [mM]", title="Sulfate vs Magnetite", xscale="log", ylim=[0,30])
comp_axs[1].set(xlabel="Magnetite [ppm]", ylabel="TOC [wt. %]", title="TOC vs Magnetite at ODP Site 1109", xscale="log", ylim=(-0.15,2))
comp_figs[0].savefig("outputs/ishikawa2002/1109/sulf-comp.pdf", bbox_inches="tight")
#comp_figs[1].savefig("outputs/ishikawa2002/1109/toc-comp.pdf")

# plot the sed rate comp plot separately, since it has a different presentation
sed_fig, sed_ax, sed_sc = data_fns.sed_avg_plot(interpolated)
sed_ax.set(xlabel="Magnetite [ppm]", ylabel="Sedimentation Rate [m/Myr]", title = "Sedimentation Rate vs Magnetite at ODP Site 1109")
#sed_fig.savefig("outputs/ishikawa2002/1109/sed-comp-lin.pdf")
# Out:
# [Text(0.5, 0, 'Magnetite [ppm]'),
#  Text(0, 0.5, 'Sedimentation Rate [m/Ma]'),
#  Text(0.5, 1.0, 'Sedimentation Rate vs Magnetite at ODP Site 1109')]

# %%
# write data to compilations
data_fns.write_output(comb_df, "ODP 180-1109", "data/comp_raw.xlsx")
data_fns.write_output(interpolated, "ODP 180-1109", "data/comp_inter.xlsx")
