# %%
# Jack Kreisler, Dartmouth College, May 2020

# import and read stuff
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel("data/chen2017_MD12-3432_Ms-age-TOC-IW.xlsx")
df
# Out:
#      Depth [m]  Age [ka BP]  Bc [mT]  Bcr [mT]  Ms [nA/m**2]  Mrs [nA/m**2]  \
# 0          0.0         7.60   17.020     46.85         99.67         21.630
# 1          0.2         8.31   12.870     34.18         93.65         15.790
# 2          0.4         9.03   12.950     34.76         88.09         14.700
# 3          0.6         9.74   13.010     35.19         66.64         11.010
# 4          0.8        10.46   13.910     36.68         63.50         11.030
# ..         ...          ...      ...       ...           ...            ...
# 316       50.2       398.53    6.857     32.85         72.91          6.634
# 317       50.4       400.43    7.300     34.89         64.70          5.874
# 318       50.5       401.38    9.312     31.60         54.99          5.558
# 319       50.6       402.34    8.135     33.37         88.15          8.404
# 320       50.8       404.24    8.740     36.93         61.20          6.065
#
#      Mass [mg]
# 0         3.63
# 1         3.61
# ...

# %%
# select columns
depth = df["Depth [m]"]
ms = df["Ms [nA/m**2]"]
mrs = df["Mrs [nA/m**2]"]

# %%
# plot and show
plt.figure()
plt.plot(ms, depth, "ro")
plt.xlabel("Ms [nA/m**2]")
plt.ylabel("Depth [m]")
plt.figure()
plt.plot(ms, mrs, "bo")
plt.xlabel("Ms [nA/m**2]")
plt.ylabel("Mrs [nA/m**2]")
#plt.show()
#plt.savefig("test-save.pdf")
# Out:
# Text(0, 0.5, 'Mrs [nA/m**2]')
